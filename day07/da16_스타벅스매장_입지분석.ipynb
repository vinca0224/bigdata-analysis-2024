# %% [markdown]
# ## 빅데이터 실습
#
# ### 스타벅스매장 입지 분석
#
# #### 데이터 수집
#
# ##### 데이터 전처리 마무리

# %%
# 필요라이브러리 사용등록
import pandas as pd

# %%
# 스타벅스 서울시 매장정보 로드
dfStarbucksSeoul = pd.read_excel('./data/startbucks_seoul_list.xlsx')
dfStarbucksSeoul
# Out:
#          매장명         위도          경도     매장타입  \
# 0    역삼아레나빌딩  37.501087  127.043069  general
# 1     논현역사거리  37.510178  127.022223  general
# 2    신사역성일빌딩  37.513931  127.020606  general
# 3     국기원사거리  37.499517  127.031495  general
# 4     대치재경빌딩  37.494668  127.062583  general
# ..       ...        ...         ...      ...
# 608     사가정역  37.579594  127.087966  general
# 609      상봉역  37.596890  127.086470  general
# 610       묵동  37.615368  127.076633  general
# 611      양원역  37.606654  127.106360  general
# 612      중화역  37.601709  127.078411  general
#
#                                         주소       전화번호
# 0                  서울특별시 강남구 언주로 425 (역삼동)  1522-3232
# 1                 서울특별시 강남구 강남대로 538 (논현동)  1522-3232
# 2                 서울특별시 강남구 강남대로 584 (논현동)  1522-3232
# 3                 서울특별시 강남구 테헤란로 125 (역삼동)  1522-3232
# 4               서울특별시 강남구 남부순환로 2947 (대치동)  1522-3232
# ..                                     ...        ...
# 608                      서울특별시 중랑구 면목로 310  1522-3232
# 609                서울특별시 중랑구 망우로 307 (상봉동)  1522-3232
# 610  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  1522-3232
# 611              서울특별시 중랑구 양원역로10길 3 (망우동)  1522-3232
# 612                   서울특별시 중랑구 봉화산로 35 1층  1522-3232
#
# [613 rows x 6 columns]

# %%
# 주소를 ' ' 로 자른다음(배열) 1번째 인덱스 값이 구
guName = []
for address in dfStarbucksSeoul['주소']:
    addr = address.split(' ')
    guName.append(addr[1])

dfStarbucksSeoul['구'] = guName

# %%
dfStarbucksSeoul.tail()
# Out:
#      Unnamed: 0   매장명         위도         경도    매장 타입  \
# 608         608  사가정역  37.579594  37.579594  general
# 609         609   상봉역  37.596890  37.596890  general
# 610         610    묵동  37.615368  37.615368  general
# 611         611   양원역  37.606654  37.606654  general
# 612         612   중화역  37.601709  37.601709  general
#
#                                         주소       전화번호    구
# 608                      서울특별시 중랑구 면목로 310  1522-3232  중랑구
# 609                서울특별시 중랑구 망우로 307 (상봉동)  1522-3232  중랑구
# 610  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  1522-3232  중랑구
# 611              서울특별시 중랑구 양원역로10길 3 (망우동)  1522-3232  중랑구
# 612                   서울특별시 중랑구 봉화산로 35 1층  1522-3232  중랑구

# %%
dfStarbucksSeoul.to_excel('./data/최종_서울_스타벅스매장리스트.xlsx', index=False)

# %%
# 스타벅스 분석 데이터 만들기
dfSeoulGu = pd.read_excel('./data/수정_서울_시군구_위경도.xlsx')
dfSeoulGu.tail()
# Out:
#    docity  do city   longitude   latitude
# 20  서울용산구  서울  용산구  126.967522  37.536094
# 21  서울은평구  서울  은평구  126.931242  37.599969
# 22  서울종로구  서울  종로구  126.981642  37.570378
# 23   서울중구  서울   중구  126.999642  37.561003
# 24  서울중랑구  서울  중랑구  127.094778  37.603806

# %%
# docity 컬럼 삭제, 위경도 위치변경
dfSeoulGuLast = dfSeoulGu[['do','city','latitude','longitude']]

# %%
# 각 컬럼의 영어이름을 한글 이름으로 변경
dfSeoulGuLast.columns = ['시','구','위도','경도']

# %%
dfSeoulGuLast.tail()
# Out:
#      시    구         위도          경도
# 20  서울  용산구  37.536094  126.967522
# 21  서울  은평구  37.599969  126.931242
# 22  서울  종로구  37.570378  126.981642
# 23  서울   중구  37.561003  126.999642
# 24  서울  중랑구  37.603806  127.094778

# %%
dfSeoulGuLast.to_excel('./data/최종_서울_구리스트.xlsx', index=False)

# %%
# 스타벅스 매장에서 구로 그룹화, 매장명수 카운팅
starbucksSeoulCount =dfStarbucksSeoul.pivot_table(values='매장명', index='구',
                                                  aggfunc='count').rename(columns={'매장명':'매장수'})
starbucksSeoulCount.tail()
# Out:
#      매장수
# 구
# 용산구   24
# 은평구   14
# 종로구   40
# 중구    54
# 중랑구    8

# %%
starbucksSeoulCount.reset_index()
# Out:
#        구  매장수
# 0    강남구   91
# 1    강동구   17
# 2    강북구    6
# 3    강서구   27
# 4    관악구   12
# 5    광진구   18
# 6    구로구   14
# 7    금천구   13
# 8    노원구   14
# 9    도봉구    7
# 10  동대문구   13
# 11   동작구   11
# 12   마포구   36
# 13  서대문구   22
# 14   서초구   48
# 15   성동구   14
# 16   성북구   15
# 17   송파구   36
# 18   양천구   17
# 19  영등포구   42
# 20   용산구   24
# 21   은평구   14
# 22   종로구   40
# 23    중구   54
# 24   중랑구    8

# %%
# 서울구 리스트에 스타벅스구별 매장수를 병합, last를 앞에 붙이면 진짜 최종 데이터!!
lastSbSeoulCount = pd.merge(left=dfSeoulGuLast, right=starbucksSeoulCount, how='left', on='구')

# %%
# 서울시 구별 인구통계 로드
dfSeoulGuPop = pd.read_excel('./data/수정_서울_구별인구.xlsx')
dfSeoulGuPop
# Out:
#        구     세대소계     성별소계       남자       여자    한국인소계     남자.1     여자.1  \
# 0     소계  4469417  9638799  4649446  4989353  9386034  4540031  4846003
# 1    종로구    72067   150453    71890    78563   139417    67306    72111
# 2     중구    64714   131793    63495    68298   121312    58659    62653
# 3    용산구   107825   227106   109826   117280   213151   102312   110839
# 4    성동구   133089   284766   137620   147146   277361   134519   142842
# 5    광진구   170077   351180   167562   183618   335554   161277   174277
# 6   동대문구   172801   359873   174120   185753   341149   167346   173803
# 7    중랑구   188097   387470   189462   198008   382155   187372   194783
# 8    성북구   196800   438168   208682   229486   425602   204171   221431
# 9    강북구   143560   292977   141185   151792   288113   139514   148599
# 10   도봉구   138261   309494   149675   159819   306948   148796   158152
# 11   노원구   217904   502925   241099   261826   498213   239117   259096
# 12   은평구   215721   470869   223330   247539   466770   221725   245045
# 13  서대문구   146845   320629   149879   170750   306231   145404   160827
# 14   마포구   181090   375162   174073   201089   363697   169990   193707
# 15   양천구   180695   439252   214161   225091   436028   212835   223193
# 16   강서구   274084   568826   272338   296488   563058   269822   293236
# 17   구로구   184096   415651   204715   210936   392405   192341   200064
# 18   금천구   120381   241105   121592   119513   227481   114414   113067
# 19  영등포구   190737   397800   195493   202307   374794   183726   191068
# 20   동작구   186675   389714   187623   202091   378769   183153   195616
# 21   관악구   284578   497883   249026   248857   481956   242651   239305
# 22   서초구   169884   412078   196391   215687   407664   194291   213373
# 23   강남구   239775   550282   262991   287291   544873   260520   284353
# 24   송파구   285927   660025   316981   343044   654166   314347   339819
# 25   강동구   203734   463318   226237   237081   459167   224423   234744
#
#     등록외국인소계    남자.2    여자.2  세대당인구    65세이상
# 0    252765  109415  143350   2.10  1743696
# 1     11036    4584    6452   1.93    28764
# 2     10481    4836    5645   1.87    25920
# 3     13955    7514    6441   1.98    39747
# 4      7405    3101    4304   2.08    49462
# 5     15626    6285    9341   1.97    56819
# 6     18724    6774   11950   1.97    67030
# 7      5315    2090    3225   2.03    78955
# 8     12566    4511    8055   2.16    80414
# 9      4864    1671    3193   2.01    68617
# 10     2546     879    1667   2.22    70436
# 11     4712    1982    2730   2.29    96422
# 12     4099    1605    2494   2.16    93817
# 13    14398    4475    9923   2.09    58113
# 14    11465    4083    7382   2.01    57895
# 15     3224    1326    1898   2.41    76317
# 16     5768    2516    3252   2.05   102096
# 17    23246   12374   10872   2.13    79984
# 18    13624    7178    6446   1.89    45342
# 19    23006   11767   11239   1.96    67509
# 20    10945    4470    6475   2.03    70474
# 21    15927    6375    9552   1.69    85418
# 22     4414    2100    2314   2.40    65661
# 23     5409    2471    2938   2.27    86606
# 24     5859    2634    3225   2.29   108894
# 25     4151    1814    2337   2.25    82984

# %%
dfSeoulGuPop[['구','성별소계']]
# Out:
#        구     성별소계
# 0     소계  9638799
# 1    종로구   150453
# 2     중구   131793
# 3    용산구   227106
# 4    성동구   284766
# 5    광진구   351180
# 6   동대문구   359873
# 7    중랑구   387470
# 8    성북구   438168
# 9    강북구   292977
# 10   도봉구   309494
# 11   노원구   502925
# 12   은평구   470869
# 13  서대문구   320629
# 14   마포구   375162
# 15   양천구   439252
# 16   강서구   568826
# 17   구로구   415651
# 18   금천구   241105
# 19  영등포구   397800
# 20   동작구   389714
# 21   관악구   497883
# 22   서초구   412078
# 23   강남구   550282
# 24   송파구   660025
# 25   강동구   463318

# %%
lastSbSeoulCount= pd.merge(left=lastSbSeoulCount, right=dfSeoulGuPop[['구','성별소계']], how='left', on='구')

# %%
lastSbSeoulCount.tail()
# Out:
#      시    구         위도          경도  매장수    성별소계
# 20  서울  용산구  37.536094  126.967522   24  227106
# 21  서울  은평구  37.599969  126.931242   14  470869
# 22  서울  종로구  37.570378  126.981642   40  150453
# 23  서울   중구  37.561003  126.999642   54  131793
# 24  서울  중랑구  37.603806  127.094778    8  387470

# %%
# 사업체 정보에 들어올 종사자수 컬럼이름이 ' 성별소계'로 동일, 컬럼이름 변경
lastSbSeoulCount.columns = ['시','구','위도','경도','스타벅스매장수','주민등록인구']

# %%
# 사업체 정보 로드
dfSeoulGuBiz = pd.read_excel('./data/수정_서울_구별사업체.xlsx')
dfSeoulGuBiz.tail()
# Out:
#       구      소계  여성대표자    성별소계      남자      여자
# 21  관악구   37915  13641  128417   68392   60025
# 22  서초구   71958  23066  487976  290084  197892
# 23  강남구  110007  35453  801419  447809  353610
# 24  송파구   74531  25400  400781  244588  156193
# 25  강동구   41660  15226  157465   83415   74050

# %%
# 사업체정보에서 컬럼이름 부터 변경
dfSeoulGuBiz= dfSeoulGuBiz[['구','소계','성별소계']]
dfSeoulGuBiz.columns = ['구','사업체수','종사자수']

# %%
# 사업체정보를 스타벅스 최종데이터에 병합
lastSbSeoulCount= pd.merge(left=lastSbSeoulCount, right=dfSeoulGuBiz, how='left', on='구')

# %%
lastSbSeoulCount.to_excel('./data/최종_서울_스타벅스매장_데이터.xlsx',index=False)

# %% [markdown]
# ## 시각화

# %%
# 시각화 라이브러리 사용등록
import folium
import json

# %%
# 새로 엑셀에서 서울시 스타벅스 매장위치 데이터 로드
dfStarbucksSeoul = pd.read_excel('./data/최종_서울_스타벅스매장리스트.xlsx')
dfStarbucksSeoul
# Out:
#          매장명         위도          경도    매장 타입  \
# 0    역삼아레나빌딩  37.501087  127.043069  general
# 1     논현역사거리  37.510178  127.022223  general
# 2    신사역성일빌딩  37.513931  127.020606  general
# 3     국기원사거리  37.499517  127.031495  general
# 4     대치재경빌딩  37.494668  127.062583  general
# ..       ...        ...         ...      ...
# 608     사가정역  37.579594  127.087966  general
# 609      상봉역  37.596890  127.086470  general
# 610       묵동  37.615368  127.076633  general
# 611      양원역  37.606654  127.106360  general
# 612      중화역  37.601709  127.078411  general
#
#                                         주소       전화번호    구
# 0                  서울특별시 강남구 언주로 425 (역삼동)  1522-3232  강남구
# 1                 서울특별시 강남구 강남대로 538 (논현동)  1522-3232  강남구
# 2                 서울특별시 강남구 강남대로 584 (논현동)  1522-3232  강남구
# 3                 서울특별시 강남구 테헤란로 125 (역삼동)  1522-3232  강남구
# 4               서울특별시 강남구 남부순환로 2947 (대치동)  1522-3232  강남구
# ..                                     ...        ...  ...
# 608                      서울특별시 중랑구 면목로 310  1522-3232  중랑구
# 609                서울특별시 중랑구 망우로 307 (상봉동)  1522-3232  중랑구
# 610  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  1522-3232  중랑구
# 611              서울특별시 중랑구 양원역로10길 3 (망우동)  1522-3232  중랑구
# 612                   서울특별시 중랑구 봉화산로 35 1층  1522-3232  중랑구
#
# [613 rows x 7 columns]

# %%
# 새로 엑셀에서 불러옴
dfStarbucksSeoulCount = pd.read_excel('./data/최종_서울_스타벅스매장_데이터.xlsx')
dfStarbucksSeoulCount
# Out:
#      시     구         위도          경도  스타벅스매장수  주민등록인구    사업체수    종사자수
# 0   서울   강남구  37.514575  127.049556       91  550282  110007  801419
# 1   서울   강동구  37.527367  127.125864       17  463318   41660  157465
# 2   서울   강북구  37.636956  127.027719        6  292977   26385   80222
# 3   서울   강서구  37.548156  126.851675       27  568826   58806  290473
# 4   서울   관악구  37.475386  126.953844       12  497883   37915  128417
# 5   서울   광진구  37.535739  127.084533       18  351180   33706  129707
# 6   서울   구로구  37.492650  126.889597       14  415651   52791  240689
# 7   서울   금천구  37.449108  126.904197       13  241105   47964  255449
# 8   서울   노원구  37.651461  127.058389       14  502925   37909  133398
# 9   서울   도봉구  37.665833  127.049522        7  309494   25391   79097
# 10  서울  동대문구  37.571625  127.042142       13  359873   42813  146383
# 11  서울   동작구  37.509656  126.941575       11  389714   27915  109281
# 12  서울   마포구  37.560706  126.910531       36  375162   56782  279788
# 13  서울  서대문구  37.576367  126.938897       22  320629   28522  118256
# 14  서울   서초구  37.480786  127.034811       48  412078   71958  487976
# 15  서울   성동구  37.560611  127.039000       14  284766   41665  203221
# 16  서울   성북구  37.586383  127.020333       15  438168   34712  124004
# 17  서울   송파구  37.511756  127.107931       36  660025   74531  400781
# 18  서울   양천구  37.514231  126.868708       17  439252   37929  133776
# 19  서울  영등포구  37.523611  126.898342       42  397800   74562  435017
# 20  서울   용산구  37.536094  126.967522       24  227106   29680  152605
# 21  서울   은평구  37.599969  126.931242       14  470869   36509  109031
# 22  서울   종로구  37.570378  126.981642       40  150453   48361  275063
# 23  서울    중구  37.561003  126.999642       54  131793   70308  386564
# 24  서울   중랑구  37.603806  127.094778        8  387470   39310  113144

# %%
# 서울시 지도 생성
seoulLoc = [37.550800, 126.989857]
seoulMap = folium.Map(location=seoulLoc, zoom_start=11)

# 각 매장별 위치를 지도에 마커로 표시
for idx in dfStarbucksSeoul.index:
    lat = dfStarbucksSeoul.loc[idx, '위도']
    lng = dfStarbucksSeoul.loc[idx, '경도']

    folium.CircleMarker(location=[lat, lng]).add_to(seoulMap)

seoulMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56f79d73e28e3dc5c3ec14b773823740 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56f79d73e28e3dc5c3ec14b773823740&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56f79d73e28e3dc5c3ec14b773823740 = L.map(
#                 &quot;map_56f79d73e28e3dc5c3ec14b773823740&quot;,
#                 {
#                     center: [37.5508, 126.989857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17c2123b38bf6d16929a8cb792e3fa87 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_17c2123b38bf6d16929a8cb792e3fa87.addTo(map_56f79d73e28e3dc5c3ec14b773823740);
#
#
#             var circle_marker_185539d8ee7219f49dfdad7922dd84d4 = L.circleMarker(
#                 [37.501087, 127.043069],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_56f79d73e28e3dc5c3ec14b773823740);
#
#
#             var circle_marker_8e45cbb423bea6b69cd9b281e0299560 = L.circleMarker(
#                 [37.510178, 127.022223],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_56f79d73e28e3dc5c3ec14b773823740);
#
#
#             var circle_marker_9e621660eaf2536142bd7aaab66564b6 = L.circleMarker(
#                 [37.5139309, 127.0206057],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_56f79d73e28e3dc5c3ec14b773823740);
#
#
#             var circle_marker_02257b2857a664eeb2e7f89cb4fb9343 = L.circleMarker(
#                 [37.499517, 127.031495],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_56f79d73e28e3dc5c3ec14b773823740);
#
#
#             var circle_marker_5136ddc34a3f63c6db621caac2f972a1 = L.circleMarker(
#                 [37.494668, 127.062583],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_56f79d73e28e3dc5c3ec14b773823740);
#
#
#             var circle_marker_555cb11d1e883a2c37947eadaef88d26 = L.circleMarker(
#                 [37.515, 127.063196],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_56f79d73e28e3dc5c3ec14b773823740);
#
#
#             var circle_marker_f04dad191785564a8b31a14e727f947c = L.circleMarker(
#                 [37.5227934, 127.0286009]

# %%
# 서울 시 구별 스타벅스 매장 수 시각화
dfStarbucksSeoulCount = pd.read_excel('./data/최종_서울_스타벅스매장_데이터.xlsx')
dfStarbucksSeoulCount.tail()
# Out:
#      시    구         위도          경도  스타벅스매장수  주민등록인구   사업체수    종사자수
# 20  서울  용산구  37.536094  126.967522       24  227106  29680  152605
# 21  서울  은평구  37.599969  126.931242       14  470869  36509  109031
# 22  서울  종로구  37.570378  126.981642       40  150453  48361  275063
# 23  서울   중구  37.561003  126.999642       54  131793  70308  386564
# 24  서울  중랑구  37.603806  127.094778        8  387470  39310  113144

# %%
# 서울 시 행정구역(구별) 경계지도 파일
path = './data/seoul_municipalities_geo_simple.json'
seoulGeoSimple = json.load(open(path, encoding='utf-8'))

# %%
seoulGeoSimple['features'][0]['properties']
# Out:
# {'code': '11250',
#  'name': '강동구',
#  'name_eng': 'Gangdong-gu',
#  'base_year': '2013'}

# %%
def style_function(feature):
    return{
        'opacity' : 0.7,
        'weight' : 1,
        'color' : 'white',
        'fillOpacity' : 0,
        'dashArrary' : '5, 3'
    }

# %%
## 지도 생성
sbCountMap = folium.Map(location= seoulLoc, zoom_start=11, tiles='CartoDB.dark_matter')

folium.GeoJson(seoulGeoSimple, style_function=style_function).add_to(sbCountMap)


sbCountMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4889a4f68f91874980d760f86a9ecfc9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4889a4f68f91874980d760f86a9ecfc9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4889a4f68f91874980d760f86a9ecfc9 = L.map(
#                 &quot;map_4889a4f68f91874980d760f86a9ecfc9&quot;,
#                 {
#                     center: [37.5508, 126.989857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a6e6b11a35b50c88ad6e0c9c83f6e81 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2a6e6b11a35b50c88ad6e0c9c83f6e81.addTo(map_4889a4f68f91874980d760f86a9ecfc9);
#
#
#         function geo_json_fe789b5aeb1aeaef41a21fd0103cce97_styler(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;dashArrary&quot;: &quot;5, 3&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 0.7, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_fe789b5aeb1aeaef41a21fd0103cce97_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_fe789b5aeb1aeaef41a21fd0103cce97 = L.geoJson(null, {
#                 onEachFeature: geo_json_fe789b5aeb1aeaef41a21fd0103cce97_onEachFeature,
#
#                 style: geo_json_fe789b5aeb1aeaef41a21fd0103cce97_styler,
#         });
#
#         function geo_json_fe789b5aeb1aeaef41a21fd0103cce97_add (data) {
#             geo_json_fe789b5aeb1aeaef41a21fd0103cce97
#                 .addData(data);
#         }
#             geo_json_fe789b5aeb1aeaef41a21fd0103cce97_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.50578973782813], [127.14324986168657, 37.502649431479774], [127.1473517108062, 37.50069754405746], [127.149801196469

# %%
## 스타벅스 평균 매장수 계산 (구별 평균 24.52개의 매장 존재)
sbMean = dfStarbucksSeoulCount['스타벅스매장수'].mean()

# %%
## 지도 생성
sbCountMap = folium.Map(location= seoulLoc, zoom_start=11, tiles='CartoDB.dark_matter')

folium.GeoJson(seoulGeoSimple, style_function=style_function).add_to(sbCountMap)

for idx in dfStarbucksSeoulCount.index:
    lat = dfStarbucksSeoulCount.loc[idx, '위도']
    lng = dfStarbucksSeoulCount.loc[idx, '경도']
    count = dfStarbucksSeoulCount.loc[idx, '스타벅스매장수']
    guName = dfStarbucksSeoulCount.loc[idx, '구']

    if count > sbMean : fillColor = 'red'
    else : fillColor = 'blue'

    folium.CircleMarker(location=[lat,lng], popup= guName + '/' + str(count), 
                        color = '#FFFF00', fill_color=fillColor, fill_opacity=0.7, 
                        weight=1.5, radius=count/2).add_to(sbCountMap)

sbCountMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_237d0c91ec24b3f4d85ace63d111688a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_237d0c91ec24b3f4d85ace63d111688a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_237d0c91ec24b3f4d85ace63d111688a = L.map(
#                 &quot;map_237d0c91ec24b3f4d85ace63d111688a&quot;,
#                 {
#                     center: [37.5508, 126.989857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eac4a762c7cb4b99e64b299bf5b6aa71 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eac4a762c7cb4b99e64b299bf5b6aa71.addTo(map_237d0c91ec24b3f4d85ace63d111688a);
#
#
#         function geo_json_35bede8bc4e39cefc4a85c0a417feec3_styler(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;dashArrary&quot;: &quot;5, 3&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 0.7, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_35bede8bc4e39cefc4a85c0a417feec3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_35bede8bc4e39cefc4a85c0a417feec3 = L.geoJson(null, {
#                 onEachFeature: geo_json_35bede8bc4e39cefc4a85c0a417feec3_onEachFeature,
#
#                 style: geo_json_35bede8bc4e39cefc4a85c0a417feec3_styler,
#         });
#
#         function geo_json_35bede8bc4e39cefc4a85c0a417feec3_add (data) {
#             geo_json_35bede8bc4e39cefc4a85c0a417feec3
#                 .addData(data);
#         }
#             geo_json_35bede8bc4e39cefc4a85c0a417feec3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.50578973782813], [127.14324986168657, 37.502649431479774], [127.1473517108062, 37.50069754405746], [127.149801196469

# %%
from folium.features import DivIcon # html로 텍스트 표시 할 아이콘 모듈 추가

# %%
dfStarbucksSeoulCount.loc[8, '위도'] = 37.653320
dfStarbucksSeoulCount.loc[8, '경도'] = 127.074440

# %%
## 구별 스타벅스 매장 수 시각화
## 지도 생성
from folium import DivIcon


sbCountMap = folium.Map(location= seoulLoc, zoom_start=11)

folium.GeoJson(seoulGeoSimple, style_function=style_function).add_to(sbCountMap)

folium.Choropleth(geo_data=seoulGeoSimple, data=dfStarbucksSeoulCount, columns=['구', '스타벅스매장수'],
                  legend_name= '구별 스타벅스 매장수',
                  fill_color='YlGn', fill_opacity=0.7, line_opacity= 0.5, key_on='properties.name').add_to(sbCountMap)

for idx in dfStarbucksSeoulCount.index:
    lat = dfStarbucksSeoulCount.loc[idx, '위도']
    lng = dfStarbucksSeoulCount.loc[idx, '경도']
    count = dfStarbucksSeoulCount.loc[idx, '스타벅스매장수']
    guName = dfStarbucksSeoulCount.loc[idx, '구']

    # 마커와 DivIcon으로 지도에 텍스트 표시
    folium.Marker(location=[lat, lng], icon=DivIcon(
        icon_size=(150,60), icon_anchor=(75,25),
        html =f'''
        <div style="font-size: 10pt; font-weight: bold, color:black; text-align: center:">
            {guName} / {count}
        </div>
        '''
    )).add_to(sbCountMap) # type: ignore

sbCountMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ff6f0fb4ba0b37c1a8e3d3dfce350fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ff6f0fb4ba0b37c1a8e3d3dfce350fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ff6f0fb4ba0b37c1a8e3d3dfce350fe = L.map(
#                 &quot;map_0ff6f0fb4ba0b37c1a8e3d3dfce350fe&quot;,
#                 {
#                     center: [37.5508, 126.989857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d09d52073f69db310e589a1b84b977e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8d09d52073f69db310e589a1b84b977e.addTo(map_0ff6f0fb4ba0b37c1a8e3d3dfce350fe);
#
#
#         function geo_json_9d83f4fccdfb9b7bc509c320e9153ddb_styler(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;dashArrary&quot;: &quot;5, 3&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 0.7, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_9d83f4fccdfb9b7bc509c320e9153ddb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_9d83f4fccdfb9b7bc509c320e9153ddb = L.geoJson(null, {
#                 onEachFeature: geo_json_9d83f4fccdfb9b7bc509c320e9153ddb_onEachFeature,
#
#                 style: geo_json_9d83f4fccdfb9b7bc509c320e9153ddb_styler,
#         });
#
#         function geo_json_9d83f4fccdfb9b7bc509c320e9153ddb_add (data) {
#             geo_json_9d83f4fccdfb9b7bc509c320e9153ddb
#                 .addData(data);
#         }
#             geo_json_9d83f4fccdfb9b7bc509c320e9153ddb_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.50578973782813], [127.14324986168657, 37.502649431479774], [127.1473517108062, 37.50069754405746], [127.14980119646964,

# %%
## 서울시 구별 인구수 지도 시각화
## 지도 생성
from folium import DivIcon


sbCountMap = folium.Map(location= seoulLoc, zoom_start=11)

folium.GeoJson(seoulGeoSimple, style_function=style_function).add_to(sbCountMap)

folium.Choropleth(geo_data=seoulGeoSimple, data=dfStarbucksSeoulCount, columns=['구', '주민등록인구'],
                  legend_name= '구별 인구분포',
                  fill_color='YlOrRd', fill_opacity=0.7, line_opacity= 0.5, key_on='properties.name').add_to(sbCountMap)

for idx in dfStarbucksSeoulCount.index:
    lat = dfStarbucksSeoulCount.loc[idx, '위도']
    lng = dfStarbucksSeoulCount.loc[idx, '경도']
    count = dfStarbucksSeoulCount.loc[idx, '주민등록인구']
    guName = dfStarbucksSeoulCount.loc[idx, '구']

    # 마커와 DivIcon으로 지도에 텍스트 표시
    folium.Marker(location=[lat, lng], icon=DivIcon(
        icon_size=(150,60), icon_anchor=(75,25),
        html =f'''
        <div style="font-size: 10pt; font-weight: bold, color:black; text-align: center:">
            {guName} / {count}
        </div>
        '''
    )).add_to(sbCountMap) # type: ignore

sbCountMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c06c53a3d59f2283f2e0c8e15a222b91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c06c53a3d59f2283f2e0c8e15a222b91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c06c53a3d59f2283f2e0c8e15a222b91 = L.map(
#                 &quot;map_c06c53a3d59f2283f2e0c8e15a222b91&quot;,
#                 {
#                     center: [37.5508, 126.989857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a7243f22efbb620213a029e82d6b608 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2a7243f22efbb620213a029e82d6b608.addTo(map_c06c53a3d59f2283f2e0c8e15a222b91);
#
#
#         function geo_json_dcb30f4245ac9ace139570ddb5b5fbf6_styler(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;dashArrary&quot;: &quot;5, 3&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 0.7, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_dcb30f4245ac9ace139570ddb5b5fbf6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_dcb30f4245ac9ace139570ddb5b5fbf6 = L.geoJson(null, {
#                 onEachFeature: geo_json_dcb30f4245ac9ace139570ddb5b5fbf6_onEachFeature,
#
#                 style: geo_json_dcb30f4245ac9ace139570ddb5b5fbf6_styler,
#         });
#
#         function geo_json_dcb30f4245ac9ace139570ddb5b5fbf6_add (data) {
#             geo_json_dcb30f4245ac9ace139570ddb5b5fbf6
#                 .addData(data);
#         }
#             geo_json_dcb30f4245ac9ace139570ddb5b5fbf6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.50578973782813], [127.14324986168657, 37.502649431479774], [127.1473517108062, 37.50069754405746], [127.14980119646964,

# %%
## 서울시 구별 사업체수 지도 시각화
## 지도 생성
from folium import DivIcon


sbCountMap = folium.Map(location= seoulLoc, zoom_start=11)

folium.GeoJson(seoulGeoSimple, style_function=style_function).add_to(sbCountMap)

folium.Choropleth(geo_data=seoulGeoSimple, data=dfStarbucksSeoulCount, columns=['구', '사업체수'],
                  legend_name= '구별 인구분포',
                  fill_color='PuBu', fill_opacity=0.7, line_opacity= 0.5, key_on='properties.name').add_to(sbCountMap)

for idx in dfStarbucksSeoulCount.index:
    lat = dfStarbucksSeoulCount.loc[idx, '위도']
    lng = dfStarbucksSeoulCount.loc[idx, '경도']
    count = dfStarbucksSeoulCount.loc[idx, '사업체수']
    guName = dfStarbucksSeoulCount.loc[idx, '구']

    # 마커와 DivIcon으로 지도에 텍스트 표시
    folium.Marker(location=[lat, lng], icon=DivIcon(
        icon_size=(150,60), icon_anchor=(75,25),
        html =f'''
        <div style="font-size: 10pt; font-weight: bold, color:black; text-align: center:">
            {guName} / {count}
        </div>
        '''
    )).add_to(sbCountMap) # type: ignore

sbCountMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1c56becdbadf7ad8e00a54a18ae555a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1c56becdbadf7ad8e00a54a18ae555a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1c56becdbadf7ad8e00a54a18ae555a = L.map(
#                 &quot;map_a1c56becdbadf7ad8e00a54a18ae555a&quot;,
#                 {
#                     center: [37.5508, 126.989857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b71c4d8ec529b2e0d46d5375fefecf6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5b71c4d8ec529b2e0d46d5375fefecf6.addTo(map_a1c56becdbadf7ad8e00a54a18ae555a);
#
#
#         function geo_json_8c80e679b2546d30369a1c049a75d66a_styler(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;dashArrary&quot;: &quot;5, 3&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 0.7, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_8c80e679b2546d30369a1c049a75d66a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8c80e679b2546d30369a1c049a75d66a = L.geoJson(null, {
#                 onEachFeature: geo_json_8c80e679b2546d30369a1c049a75d66a_onEachFeature,
#
#                 style: geo_json_8c80e679b2546d30369a1c049a75d66a_styler,
#         });
#
#         function geo_json_8c80e679b2546d30369a1c049a75d66a_add (data) {
#             geo_json_8c80e679b2546d30369a1c049a75d66a
#                 .addData(data);
#         }
#             geo_json_8c80e679b2546d30369a1c049a75d66a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.50578973782813], [127.14324986168657, 37.502649431479774], [127.1473517108062, 37.50069754405746], [127.14980119646964,

# %% [markdown]
# ##### 결론
# - 스타벅스는 인구수와 별개로 직장인이 많이 분포하는 구에 매장을 많이 오픈하는 것을 알 수 있다.
